# %%
import glob
import os
import sys
from pathlib import Path

# %%
import numpy as np
import xarray as xr
from quantify.data.handling import load_dataset, load_snapshot

from quantify.data.handling import get_datadir, set_datadir

from quantify.data import handling as dh

# %%
set_datadir("./quantify-C3-datadir/")
get_datadir()
# Out:
# './quantify-C3-datadir/'

# %%
selected_dir_name = "20210419-173649-456-23c5f3-AllXY q0"
# tuid = "20210419-173649-456-23c5f3"
tuid = "20210419-173142"
tuid = "20210419-172544"

# %%
test_dataset = load_dataset(tuid=tuid)
test_snapshot = load_snapshot(tuid=tuid)

# %%
schedules_directory = Path(get_datadir()) / "schedules" / f"{test_dataset.tuid}"

# %%
test_dataset
# Out:
# <xarray.Dataset>
# Dimensions:  (dim_0: 42)
# Coordinates:
#     x0       (dim_0) int32 0 0 1 1 2 2 3 3 4 4 ... 16 16 17 17 18 18 19 19 20 20
#     x1       (dim_0) float64 0.48 0.48 0.48 0.48 0.48 ... 0.48 0.48 0.48 0.48
#     x2       (dim_0) float64 -0.15 -0.15 -0.15 -0.15 ... -0.15 -0.15 -0.15 -0.15
#     x3       (dim_0) float64 4.715e+09 4.715e+09 ... 4.715e+09 4.715e+09
#     x4       (dim_0) object '252-740d11' '356-48b9e2' ... '511-b7ae9b'
# Dimensions without coordinates: dim_0
# Data variables:
#     y0       (dim_0) float64 1.567e-05 1.553e-05 ... 3.504e-05 3.522e-05
#     y1       (dim_0) float64 -1.604 -4.125 -3.795 -4.599 ... 3.271 2.235 3.386
#     y2       (dim_0) float64 1.348 1.436 1.326 1.319 ... 1.329 1.385 1.322 1.336
# Attributes:
#     2D-grid:  False
#     name:     AllXY q0
#     tuid:     20210419-172544-698-1304c0

# %%
test_dataset.y0.plot() # using default xarray plotting

# test_dataset.y1.plot()

# %%
from qitt_experiments.analysis.timedomain_analysis import ALLXY_Analysis
a_obj=ALLXY_Analysis(tuid=tuid)#.run() # for future releasess)
a_obj.display_figs_mpl()

# %%
for name in glob.glob(f"{str(schedules_directory)}/*"):
    print(name)
# Out:
# quantify-C3-datadir/schedules/20210419-173649-456-23c5f3/792-b38036.json
# quantify-C3-datadir/schedules/20210419-173649-456-23c5f3/092-53b2e9.json
# quantify-C3-datadir/schedules/20210419-173649-456-23c5f3/806-b4d040.json
# quantify-C3-datadir/schedules/20210419-173649-456-23c5f3/203-dd5c40.json
# quantify-C3-datadir/schedules/20210419-173649-456-23c5f3/616-2c7b22.json
# quantify-C3-datadir/schedules/20210419-173649-456-23c5f3/699-23973d.json
# quantify-C3-datadir/schedules/20210419-173649-456-23c5f3/304-bfb9ac.json
# quantify-C3-datadir/schedules/20210419-173649-456-23c5f3/114-ca1260.json
# quantify-C3-datadir/schedules/20210419-173649-456-23c5f3/093-61f52c.json
# quantify-C3-datadir/schedules/20210419-173649-456-23c5f3/421-488e24.json
# quantify-C3-datadir/schedules/20210419-173649-456-23c5f3/015-ad862a.json
# quantify-C3-datadir/schedules/20210419-173649-456-23c5f3/986-430678.json
# quantify-C3-datadir/schedules/20210419-173649-456-23c5f3/519-bee785.json
# ...
